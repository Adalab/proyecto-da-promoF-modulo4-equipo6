# %%
import pandas as pd
import numpy as np
# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("SRC/data/recursos-humanos_final.csv", index_col=0)
df.head()
# Out:
#          employee_name  empid  genderid  empstatusid  department    salary  \
# 0  Adinolfi, Wilson  K  10026       1.0            1  Production   62506.0
# 1              Unknown  10084       1.0            5       IT/IS  104437.0
# 2    Akinkuolie, Sarah  10196       0.0            5  Production   64955.0
# 3         Alagbe,Trina  10088       0.0            1  Production   64991.0
# 4     Anderson, Carol   10069       0.0            5  Production   50825.0
#
#    termd                  position state   zip  ...     managername managerid  \
# 0    0.0   Production Technician I    MA  1960  ...  Michael Albert      22.0
# 1    1.0                   Sr. DBA    MA  2148  ...      Simon Roup       4.0
# 2    1.0  Production Technician II    MA  1810  ...  Kissy Sullivan      20.0
# 3    0.0   Production Technician I    MA  1886  ...    Elijiah Gray      16.0
# 4    1.0   Production Technician I    MA  2169  ...  Webster Butler      39.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 311 entries, 0 to 310
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   employee_name               311 non-null    object
#  1   empid                       311 non-null    int64
#  2   genderid                    311 non-null    float64
#  3   empstatusid                 311 non-null    int64
#  4   department                  311 non-null    object
#  5   salary                      311 non-null    float64
#  6   termd                       311 non-null    float64
#  7   position                    311 non-null    object
#  8   state                       311 non-null    object
#  9   zip                         311 non-null    int64
#  10  date_of_birth               311 non-null    object
#  11  maritaldesc                 311 non-null    object
#  12  citizendesc                 311 non-null    object
# ...

# %%
df.describe().T
# Out:
#                       count          mean           std       min       25%  \
# empid                 311.0  10156.000000     89.922189  10001.00  10078.50
# genderid              311.0      0.434084      0.496435      0.00      0.00
# empstatusid           311.0      2.392283      1.794383      1.00      1.00
# salary                311.0  69020.684887  25156.636930  45046.00  55501.50
# termd                 311.0      0.334405      0.472542      0.00      0.00
# zip                   311.0   6555.482315  16908.396884   1013.00   1901.50
# managerid             311.0     15.199357      8.864507      1.00     10.00
# engagementsurvey      311.0      4.110000      0.789938      1.12      3.69
# empsatisfaction       311.0      3.890675      0.909241      1.00      3.00
# specialprojectscount  311.0      0.636656      1.796001      0.00      0.00
# dayslatelast30        311.0    385.665595    486.935411      0.00      0.00
# ...

# %%
numeric = df.select_dtypes(include = np.number)
numeric.columns
# Out:
# Index(['empid', 'genderid', 'empstatusid', 'salary', 'termd', 'zip',
#        'managerid', 'engagementsurvey', 'empsatisfaction',
#        'specialprojectscount', 'dayslatelast30', 'absences'],
#       dtype='object')

# %%
sns.heatmap(numeric)
# Out:
# <Axes: >
